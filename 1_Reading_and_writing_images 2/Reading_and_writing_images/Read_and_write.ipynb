# %%
# !pip install opencv-python
# !pip install ipykernel

# %%
import cv2

# %%
image = cv2.imread("./mountain.jpg")

# %%
# to check if image loaded successfully 
if image is None:
    print("image did not load successfully")
else:
    print("image loaded successfully")
# Out:
# image loaded successfully

# %%
cv2.imshow("Window image", image)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %%
image_new = image - 50 # line that update the image

# %%
cv2.imwrite("./imageNew.jpg", image_new)
# Out:
# True
